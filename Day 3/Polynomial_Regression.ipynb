# %% [markdown]
# <a href="https://colab.research.google.com/github/vishesh-07/Summer-Training/blob/main/Day%203/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files 
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f4e98a26-47bd-4390-ab44-03447ffea42a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f4e98a26-47bd-4390-ab44-03447ffea42a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving apartment_prices.csv to apartment_prices.csv

# %%
dataset = pd.read_csv('apartment_prices.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Polynomial Regression')
plt.xlabel('Squaremeter')
plt.ylabel('Price')
plt.show()

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Polynomial Regression')
plt.xlabel('Squaremeter')
plt.ylabel('Price')
plt.show()

# %%
lin_reg_2.predict(poly_reg.fit_transform([[131]]))
# Out:
# array([705.69030201])
